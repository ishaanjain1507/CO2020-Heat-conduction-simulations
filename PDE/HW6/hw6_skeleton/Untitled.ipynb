# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv(f"./primitives_x_0000.csv")
n = len(df['x'])
len(df['x'])
# Out:
# 100

# %%
rho = np.zeros((n, 318))
u = np.zeros((n, 318))
p = np.zeros((n, 318))

for i in range(318):
    t = format(i, '04d')
    df = pd.read_csv(f"./primitives_x_{t}.csv")
    DF = df.to_numpy()
    x = DF[:, 0]
    rho[:, i] = DF[:, 1]
    u[:, i] = DF[:, 2]
    p[:, i] = DF[:, 3]
    
#     plt.plot(x, rho[:, i])
#     plt.plot()
#     plt.show()
#     plt.plot(x, u[:, i])
#     plt.show()
#     plt.plot(x, p[:, i])
#     plt.show()
    #plotting the wavefunction and the probability density
#     if i%16 == 15 or i == 0:
#     plt.tight_layout()
#     fig, axis = plt.subplots(figsize = (4, 10), nrows = 3, ncols = 1)
#     axis[0].set_title(f'$ρ$ vs $x$ at $t = {DF[0, -1]}s$')
#     axis[0].set_ylabel('$ρ$')
#     axis[0].plot(x, rho[:, i])
#     axis[0].axhline(0, c = 'k')


#     axis[1].set_title(f'$u$ vs $x$ at $t = {DF[0, -1]}s$')
#     axis[1].set_ylabel('$u$')
#     axis[1].plot(x, u[:, i])
#     #       axis[1].axhline(0, c = 'k')
    
#     axis[2].set_title(f'$p$ vs $x$ at $t = {DF[0, -1]}s$')
#     axis[2].set_ylabel('$p$')
#     axis[2].plot(x, p[:, i])
    axis[2].axhline(0, c = 'k')
    
#     plt.savefig(f"./plots/plt{i}.png")
#     ais[][].set_xlabel('$x$')

# %%
rho1 = np.zeros((n, ))
u1 = np.zeros((n, 318))
p1 = np.zeros((n, 318))

for i in range(318):
    t = format(i, '04d')
    df = pd.read_csv(f"./primitives_x_{t}.csv")
    DF = df.to_numpy()
    x1 = DF[:, 0]
    rho1[:, i] = DF[:, 1]
    u1[:, i] = DF[:, 2]
    p1[:, i] = DF[:, 3]
    
#     plt.plot(x, rho[:, i])
#     plt.plot()
#     plt.show()
#     plt.plot(x, u[:, i])
#     plt.show()
#     plt.plot(x, p[:, i])
#     plt.show()
    #plotting the wavefunction and the probability density
    if i%16 == 15 or i == 0:
        plt.tight_layout()
        fig, axis = plt.subplots(figsize = (4, 10), nrows = 3, ncols = 1)
        axis[0].set_title(f'$ρ$ vs $x$ at $t = {DF[0, -1]}s$')
        axis[0].set_ylabel('$ρ$')
        axis[0].plot(x, rho[:, i], label = "Lax")
        axis[0].plot(x, rho1[:, i], label = "Lax-Wendorff")
        axis[0].axhline(0, c = 'k')
    
    
        axis[1].set_title(f'$u$ vs $x$ at $t = {DF[0, -1]}s$')
        axis[1].set_ylabel('$u$')
        axis[1].plot(x, u[:, i], label = "Lax")
        axis[1].plot(x, u1[:, i], label = "Lax-Wendorff")
        #       axis[1].axhline(0, c = 'k')
        
        axis[2].set_title(f'$p$ vs $x$ at $t = {DF[0, -1]}s$')
        axis[2].set_ylabel('$p$')
        axis[2].plot(x, p[:, i], label = "Lax")
        axis[2].plot(x, p1[:, i], label = "Lax-Wendorff")
        axis[2].axhline(0, c = 'k')
        
        plt.legend()
        
        plt.savefig(f"./plots/plt{i}.png")
#     ais[][].set_xlabel('$x$')
# Out:
# /tmp/ipykernel_42250/987298360.py:24: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axis = plt.subplots(figsize = (4, 10), nrows = 3, ncols = 1)
